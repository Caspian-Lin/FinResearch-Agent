# %% [markdown]
# # Sentiment Experiment
#
# Investigate whether news sentiment improves short-term strategy performance. TODO: Week 4.

# %%
# Week 4 placeholder — financial text sentiment scoring
# Plan:
#   1. Load news headlines / earnings summaries
#   2. Score sentiment with FinBERT or LLM classifier
#   3. Merge sentiment factor with technical indicators
#   4. Compare technical-only vs technical+sentiment strategies

print("sentiment_experiment notebook — Week 4 placeholder")
