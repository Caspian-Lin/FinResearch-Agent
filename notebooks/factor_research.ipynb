# %% [markdown]
# # Factor Research
#
# Exploratory analysis for momentum / volatility / RSI factors. TODO: Week 3.

# %%
# Week 3 placeholder — momentum factor exploration
# Import project packages and load sample OHLCV from DB.
import pandas as pd

# TODO: from app.db.session import SessionLocal
# TODO: load market_ohlcv into a DataFrame
# TODO: compute 1M / 3M / 6M momentum
# TODO: rank assets, compute IC, plot cumulative returns

print("factor_research notebook — Week 3 placeholder")
